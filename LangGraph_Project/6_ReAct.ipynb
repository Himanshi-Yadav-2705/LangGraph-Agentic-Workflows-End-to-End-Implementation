# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, ToolMessage
from langchain.tools import tool
from langchain_core.prompts import ChatPromptTemplate


from dotenv import load_dotenv
import os
load_dotenv()

if os.environ['OPENAI_API_KEY']:
    print("OpenAI API Key is set.")
else:
    raise ValueError("OpenAI API Key is not set.")
# Out:
# OpenAI API Key is set.

# %%
llm = ChatOpenAI(model="gpt-5-nano")

# %% [markdown]
# # **TOOLS**

# %% [markdown]
# ### **DuckDuckGo Search Tool**

# %%
from langchain_community.tools import DuckDuckGoSearchRun

@tool
def search_duckduckgo(query: str) -> str:

    """This tool searches the latest news on DuckDuckGo for the given query and returns the results."""
    duck_search = DuckDuckGoSearchRun()
    return duck_search.invoke(query)

# %% [markdown]
# ### **Arxiv Query Tool**

# %%
from langchain_community.tools import ArxivQueryRun
from langchain_community.utilities import ArxivAPIWrapper

@tool
def arxiv_tool(query: str) -> str:

    """"This tool allows you to query the arXiv database for research papers."""
    arxiv_query = ArxivQueryRun(api_wrapper=ArxivAPIWrapper())
    return arxiv_query.invoke(query)

# %% [markdown]
# ### **Wikipedia Search Tool**

# %%
from langchain_community.tools import WikipediaQueryRun
from langchain_community.utilities import WikipediaAPIWrapper

@tool
def wiki_tool(query: str):

    """This tool allows you to search Wikipedia for information on a given topic."""
    wiki_query = WikipediaQueryRun(api_wrapper=WikipediaAPIWrapper())
    return wiki_query.invoke(query)

# %% [markdown]
# ### **Custom Tool**

# %%
@tool
def personal_info(name: str):

    """Use this tool to get personal information about Alice, Bob, or Charlie. 
    """

    info = {
        "Alice": "Alice is a software engineer with 5 years of experience in AI.",
        "Bob": "Bob is a data scientist who loves working with large datasets.",
        "Charlie": "Charlie is a product manager with a background in tech startups."
    }
    return info.get(name, "No information available for this person.")

# %% [markdown]
# ### **TOOL BINDING**

# %%
tools = [search_duckduckgo, arxiv_tool, wiki_tool, personal_info]

llm_with_tools = llm.bind_tools(tools)

# %% [markdown]
# # **LangGraph Creation**

# %% [markdown]
# ### **Create Schema**

# %%
from typing import TypedDict, List 

class graph_schema(TypedDict):
    messages: List

# %% [markdown]
# ### **Create Node Functions**

# %%
def llm_node(state: graph_schema) -> graph_schema:
    
    messages = state['messages']

    # Prompt template for the LLM, including system instructions and the human input
    prompt = ChatPromptTemplate.from_messages(
        [
            ("system", "You are a helpful assistant that can use tools to answer questions."),
            ("human", "{input}")
        ]
    )

    # LLM With Tools 
    # llm_with_tools 

    chain = prompt | llm_with_tools 

    response = chain.invoke({"input": messages})

    # Update the state with the new message
    state['messages'] = messages + [response]

    return state

# %%
# from langgraph.prebuilt import ToolNode
def tool_node(state: graph_schema) -> graph_schema:

    messages = state['messages']

    tools_by_name = {tool.name: tool for tool in tools}

    tool_results = []

    for tool_call in messages[-1].tool_calls:

        tool = tools_by_name[tool_call["name"]]

        observation = tool.invoke(tool_call["args"])

        tool_results.append(ToolMessage(content=observation, tool_call_id=tool_call["id"]))

    # Update the state with the tool results
    state['messages'] = messages + tool_results

    return state

# %% [markdown]
# ### **Create Conditional Edge Function**

# %%
def if_tool_call(state: graph_schema) -> str:

    last_message = state['messages'][-1]

    if last_message.tool_calls:
        return "tool_node"
    else:
        return "end"

# %% [markdown]
# ### **Create State Graph**

# %%
from langgraph.graph import StateGraph, START, END

graph = StateGraph(graph_schema)

# Add nodes to the graph
graph.add_node("llm_node", llm_node)
graph.add_node("tool_node", tool_node)

# Add edges between nodes
graph.add_edge(START, "llm_node")
graph.add_conditional_edges("llm_node", if_tool_call,{"tool_node": "tool_node", "end": END})
graph.add_edge("tool_node", "llm_node")
graph.add_edge("llm_node", END)


react_graph = graph.compile()

from IPython.display import Image, display

# You could see the errors with the below command
Image(react_graph.get_graph().draw_mermaid_png())

# %% [markdown]
# ### **Graph Invocation**

# %%
react_graph.invoke({"messages": [HumanMessage(content="What is the latest news on AI?")]})
# Out:
# {'messages': [HumanMessage(content='What is the latest news on AI?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 284, 'prompt_tokens': 265, 'total_tokens': 549, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 256, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DZfNsZyelmQcN3NyBd5SO0imrc2Xf', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019dd4df-cc4a-7451-b069-19f895b7b3ed-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest AI news'}, 'id': 'call_NOLg3jqg9e4jGm8SffcxONFy', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 265, 'output_tokens': 284, 'total_tokens': 549, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 256}}),
#   ToolMessage(content='AiNews.com – Daily Artificial Intelligence News & Insights. Turning AI noise into understanding — quickly, responsibly, and clearly. Subscribe to our newsletter. AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide.View All Latest. Cybersecurity AI. Stay Ahead of AI. Get the latest AI breakthroughs, tools, and insights delivered to your inbox every week with our ChatAI newsletter. By Invitation. AI is the new Oracle of Delphi. That’s bad news. Societies urgently need to confront the ethics of prediction, writes Carissa Véliz. Read full articles, watch videos, browse thousands of titles and more on the "Mistral AI" topic with Google News.Mistral AI Raises $830M For Nvidia Data Center With 13,800 GPUs.', tool_call_id='call_NOLg3jqg9e4jGm8SffcxONFy'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1116, 'prompt_tokens': 787, 'total_tokens': 1903, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1088, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DZfO00tc7bFUgD7so4GrYOsj7OIKA', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019dd4df-ee94-7083-8956-1373be227c4a-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'AI news today'}, 'id': 'call_0jGKogjxGeOBtipZLLpX7vnw', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 787, 'output_tokens': 1116, 'total_tokens': 1903, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1088}}),
#   ToolMessage(content='Explore the latest artificial intelligence news with Reuters - from AI breakthroughs and technology trends to regulation, ethics, business and global impact. Track breaking AI news, weekly movers, beat shifts, and 113 entity trend lines — covering the last 48 hours. From AI Weekly, 475+ issues, 44K subscribers. See the latest on The AI Race. From breaking news to in-depth reporting, Bloomberg tracks the full story in real time. Daily curated AI news covering tools, models, and emerging technologies. Stay current on artificial intelligence from trusted sources. Salesforce CEO Marc Benioff announced plans to hire 1,000 graduates and interns to support expanding AI products, countering concerns about AI eliminating entry-level jobs. This hiring initiative follows news of fewer than 1,000 job cuts in February, impacting roles like marketing and product ...', tool_call_id='call_0jGKogjxGeOBtipZLLpX7vnw'),
#   AIMessage(content='Here’s a quick snapshot of recent AI news based on the latest results I pulled:\n\n- Mistral AI raises about $830 million for Nvidia-powered data center infrastructure (13,800 GPUs). This funding supports scaling AI compute capabilities and could accelerate deployment of large-scale models and services.\n\n- Ethics of AI and prediction: An evolving debate highlighted by Carissa Véliz’s take that “AI is the new Oracle of Delphi,” arguing that society must confront the ethics of AI-driven predictions and their societal impact.\n\n- Salesforce news: Salesforce CEO Marc Benioff announced plans to hire about 1,000 graduates and interns to support expanding AI products. In February there were fewer than 1,000 job cuts reported, mainly in marketing and product roles—part of broader AI- and tech-related workforce shifts.\n\nNotes:\n- These items come from the latest AI news digests and roundup-style coverage. If you’d like, I can pull more in-depth articles from specific outlets (e.g., Reuters, Bloomberg, Bloomberg Tech) or tailor the feed to a region, industry, or AI subfield (healthcare, finance, robotics, etc.).\n\nWould you like me to dive deeper into any of these stories or pull more focused news (e.g., regulatory updates, startup funding, or enterprise AI deployments)?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1872, 'prompt_tokens': 1315, 'total_tokens': 3187, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1600, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DZfOHXDiH1l30PnCjcbazHdbXlD8Y', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019dd4e0-2246-73d0-aa53-3aa128b0eb33-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1315, 'output_tokens': 1872, 'total_tokens': 3187, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1600}})]}

# %%
for chunk in react_graph.stream(
    {"messages": [HumanMessage(content="What is the latest news on AI?")]},
    stream_mode="updates"
):
    print(chunk)
# Out:
# {'llm_node': {'messages': [HumanMessage(content='What is the latest news on AI?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 348, 'prompt_tokens': 265, 'total_tokens': 613, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DZfOYbZGcM92QfYC6DKMFXKteEx6v', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019dd4e0-747c-7bc1-95eb-01c711b9bd80-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest AI news'}, 'id': 'call_UkIEZDZPR1RpPl4J18yg6w7o', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 265, 'output_tokens': 348, 'total_tokens': 613, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 320}})]}}
# {'tool_node': {'messages': [HumanMessage(content='What is the latest news on AI?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 348, 'prompt_tokens': 265, 'total_tokens': 613, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DZfOYbZGcM92QfYC6DKMFXKteEx6v', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019dd4e0-747c-7bc1-95eb-01c711b9bd80-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest AI news'}, 'id': 'call_UkIEZDZPR1RpPl4J18yg6w7o', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 265, 'output_tokens': 348, 'total_tokens': 613, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 320}}), ToolMessage(content='AiNews.com – Daily Artificial Intelligence News & Insights. Turning AI noise into understanding — quickly, responsibly, and clearly. Subscribe to our newsletter. AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide.View All Latest. Cybersecurity AI. By Invitation. AI is the new Oracle of Delphi. That’s bad news. Societies urgently need to confront the ethics of prediction, writes Carissa Véliz. Stay Ahead of AI. Get the latest AI breakthroughs, tools, and insights delivered to your inbox every week with our ChatAI newsletter. Read full articles, watch videos, browse thousands of titles and more on the "Mistral AI" topic with Google News.Mistral AI Raises $830M For Nvidia Data Center With 13,800 GPUs.', tool_call_id='call_UkIEZDZPR1RpPl4J18yg6w7o')]}}
# {'llm_node': {'messages': [HumanMessage(content='What is the latest news on AI?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 348, 'prompt_tokens': 265, 'total_tokens': 613, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DZfOYbZGcM92QfYC6DKMFXKteEx6v', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019dd4e0-747c-7bc1-95eb-01c711b9bd80-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest AI news'}, 'id': 'call_UkIEZDZPR1RpPl4J18yg6w7o', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 265, 'output_tokens': 348, 'total_tokens': 613, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 320}}), ToolMessage(content='AiNews.com – Daily Artificial Intelligence News & Insights. Turning AI noise into understanding — quickly, responsibly, and clearly. Subscribe to our newsletter. AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide.View All Latest. Cybersecurity AI. By Invitation. AI is the new Oracle of Delphi. That’s bad news. Societies urgently need to confront the ethics of prediction, writes Carissa Véliz. Stay Ahead of AI. Get the latest AI breakthroughs, tools, and insights delivered to your inbox every week with our ChatAI newsletter. Read full articles, watch videos, browse thousands of titles and more on the "Mistral AI" topic with Google News.Mistral AI Raises $830M For Nvidia Data Center With 13,800 GPUs.', tool_call_id='call_UkIEZDZPR1RpPl4J18yg6w7o'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 796, 'prompt_tokens': 787, 'total_tokens': 1583, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 768, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DZfOfdWBYBnKNP59qUttInxwEqlup', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019dd4e0-8ed8-79c0-a815-e32d160a61ab-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest AI news'}, 'id': 'call_EALEOYE35648n83JGEEoWBMV', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 787, 'output_tokens': 796, 'total_tokens': 1583, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 768}})]}}
# {'tool_node': {'messages': [HumanMessage(content='What is the latest news on AI?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 348, 'prompt_tokens': 265, 'total_tokens': 613, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DZfOYbZGcM92QfYC6DKMFXKteEx6v', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019dd4e0-747c-7bc1-95eb-01c711b9bd80-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest AI news'}, 'id': 'call_UkIEZDZPR1RpPl4J18yg6w7o', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 265, 'output_tokens': 348, 'total_tokens': 613, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 320}}), ToolMessage(content='AiNews.com – Daily Artificial Intelligence News & Insights. Turning AI noise into understanding — quickly, responsibly, and clearly. Subscribe to our newsletter. AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide.View All Latest. Cybersecurity AI. By Invitation. AI is the new Oracle of Delphi. That’s bad news. Societies urgently need to confront the ethics of prediction, writes Carissa Véliz. Stay Ahead of AI. Get the latest AI breakthroughs, tools, and insights delivered to your inbox every week with our ChatAI newsletter. Read full articles, watch videos, browse thousands of titles and more on the "Mistral AI" topic with Google News.Mistral AI Raises $830M For Nvidia Data Center With 13,800 GPUs.', tool_call_id='call_UkIEZDZPR1RpPl4J18yg6w7o'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 796, 'prompt_tokens': 787, 'total_tokens': 1583, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 768, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DZfOfdWBYBnKNP59qUttInxwEqlup', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019dd4e0-8ed8-79c0-a815-e32d160a61ab-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest AI news'}, 'id': 'call_EALEOYE35648n83JGEEoWBMV', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 787, 'output_tokens': 796, 'total_tokens': 1583, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 768}}), ToolMessage(content='9 hours ago - AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide. 6 hours ago - Explore the latest artificial intelligence news with Reuters - from AI breakthroughs and technology trends to regulation, ethics, business and global impact. 4 days ago - News coverage on artificial intelligence and machine learning tech, the companies building them, and the ethical issues AI raises today. 8 hours ago - Artificial Intelligence: Read latest updates on AI like Google AI, ChatGPT, Google Lamda, Bard chatbot and more along with latest news as AI technology advances and makes new progress. All get detailed articles on AI related queries like what is AI, types of artificial intelligence, its applications and future. GITEX AI ASIA, the Tech, Startup & Digital Investments Event, returns to Marina Bay Sands, Singapore on 9–10 April 2026.… ... Tim Cook is stepping down as CEO, after serving Appl ...
# {'llm_node': {'messages': [HumanMessage(content='What is the latest news on AI?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 348, 'prompt_tokens': 265, 'total_tokens': 613, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DZfOYbZGcM92QfYC6DKMFXKteEx6v', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019dd4e0-747c-7bc1-95eb-01c711b9bd80-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest AI news'}, 'id': 'call_UkIEZDZPR1RpPl4J18yg6w7o', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 265, 'output_tokens': 348, 'total_tokens': 613, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 320}}), ToolMessage(content='AiNews.com – Daily Artificial Intelligence News & Insights. Turning AI noise into understanding — quickly, responsibly, and clearly. Subscribe to our newsletter. AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide.View All Latest. Cybersecurity AI. By Invitation. AI is the new Oracle of Delphi. That’s bad news. Societies urgently need to confront the ethics of prediction, writes Carissa Véliz. Stay Ahead of AI. Get the latest AI breakthroughs, tools, and insights delivered to your inbox every week with our ChatAI newsletter. Read full articles, watch videos, browse thousands of titles and more on the "Mistral AI" topic with Google News.Mistral AI Raises $830M For Nvidia Data Center With 13,800 GPUs.', tool_call_id='call_UkIEZDZPR1RpPl4J18yg6w7o'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 796, 'prompt_tokens': 787, 'total_tokens': 1583, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 768, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DZfOfdWBYBnKNP59qUttInxwEqlup', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019dd4e0-8ed8-79c0-a815-e32d160a61ab-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest AI news'}, 'id': 'call_EALEOYE35648n83JGEEoWBMV', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 787, 'output_tokens': 796, 'total_tokens': 1583, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 768}}), ToolMessage(content='9 hours ago - AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide. 6 hours ago - Explore the latest artificial intelligence news with Reuters - from AI breakthroughs and technology trends to regulation, ethics, business and global impact. 4 days ago - News coverage on artificial intelligence and machine learning tech, the companies building them, and the ethical issues AI raises today. 8 hours ago - Artificial Intelligence: Read latest updates on AI like Google AI, ChatGPT, Google Lamda, Bard chatbot and more along with latest news as AI technology advances and makes new progress. All get detailed articles on AI related queries like what is AI, types of artificial intelligence, its applications and future. GITEX AI ASIA, the Tech, Startup & Digital Investments Event, returns to Marina Bay Sands, Singapore on 9–10 April 2026.… ... Tim Cook is stepping down as CEO, after serving Apple ...
# {'tool_node': {'messages': [HumanMessage(content='What is the latest news on AI?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 348, 'prompt_tokens': 265, 'total_tokens': 613, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DZfOYbZGcM92QfYC6DKMFXKteEx6v', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019dd4e0-747c-7bc1-95eb-01c711b9bd80-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest AI news'}, 'id': 'call_UkIEZDZPR1RpPl4J18yg6w7o', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 265, 'output_tokens': 348, 'total_tokens': 613, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 320}}), ToolMessage(content='AiNews.com – Daily Artificial Intelligence News & Insights. Turning AI noise into understanding — quickly, responsibly, and clearly. Subscribe to our newsletter. AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide.View All Latest. Cybersecurity AI. By Invitation. AI is the new Oracle of Delphi. That’s bad news. Societies urgently need to confront the ethics of prediction, writes Carissa Véliz. Stay Ahead of AI. Get the latest AI breakthroughs, tools, and insights delivered to your inbox every week with our ChatAI newsletter. Read full articles, watch videos, browse thousands of titles and more on the "Mistral AI" topic with Google News.Mistral AI Raises $830M For Nvidia Data Center With 13,800 GPUs.', tool_call_id='call_UkIEZDZPR1RpPl4J18yg6w7o'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 796, 'prompt_tokens': 787, 'total_tokens': 1583, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 768, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DZfOfdWBYBnKNP59qUttInxwEqlup', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019dd4e0-8ed8-79c0-a815-e32d160a61ab-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest AI news'}, 'id': 'call_EALEOYE35648n83JGEEoWBMV', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 787, 'output_tokens': 796, 'total_tokens': 1583, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 768}}), ToolMessage(content='9 hours ago - AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide. 6 hours ago - Explore the latest artificial intelligence news with Reuters - from AI breakthroughs and technology trends to regulation, ethics, business and global impact. 4 days ago - News coverage on artificial intelligence and machine learning tech, the companies building them, and the ethical issues AI raises today. 8 hours ago - Artificial Intelligence: Read latest updates on AI like Google AI, ChatGPT, Google Lamda, Bard chatbot and more along with latest news as AI technology advances and makes new progress. All get detailed articles on AI related queries like what is AI, types of artificial intelligence, its applications and future. GITEX AI ASIA, the Tech, Startup & Digital Investments Event, returns to Marina Bay Sands, Singapore on 9–10 April 2026.… ... Tim Cook is stepping down as CEO, after serving Appl ...
# {'llm_node': {'messages': [HumanMessage(content='What is the latest news on AI?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 348, 'prompt_tokens': 265, 'total_tokens': 613, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DZfOYbZGcM92QfYC6DKMFXKteEx6v', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019dd4e0-747c-7bc1-95eb-01c711b9bd80-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest AI news'}, 'id': 'call_UkIEZDZPR1RpPl4J18yg6w7o', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 265, 'output_tokens': 348, 'total_tokens': 613, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 320}}), ToolMessage(content='AiNews.com – Daily Artificial Intelligence News & Insights. Turning AI noise into understanding — quickly, responsibly, and clearly. Subscribe to our newsletter. AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide.View All Latest. Cybersecurity AI. By Invitation. AI is the new Oracle of Delphi. That’s bad news. Societies urgently need to confront the ethics of prediction, writes Carissa Véliz. Stay Ahead of AI. Get the latest AI breakthroughs, tools, and insights delivered to your inbox every week with our ChatAI newsletter. Read full articles, watch videos, browse thousands of titles and more on the "Mistral AI" topic with Google News.Mistral AI Raises $830M For Nvidia Data Center With 13,800 GPUs.', tool_call_id='call_UkIEZDZPR1RpPl4J18yg6w7o'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 796, 'prompt_tokens': 787, 'total_tokens': 1583, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 768, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DZfOfdWBYBnKNP59qUttInxwEqlup', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019dd4e0-8ed8-79c0-a815-e32d160a61ab-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest AI news'}, 'id': 'call_EALEOYE35648n83JGEEoWBMV', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 787, 'output_tokens': 796, 'total_tokens': 1583, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 768}}), ToolMessage(content='9 hours ago - AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide. 6 hours ago - Explore the latest artificial intelligence news with Reuters - from AI breakthroughs and technology trends to regulation, ethics, business and global impact. 4 days ago - News coverage on artificial intelligence and machine learning tech, the companies building them, and the ethical issues AI raises today. 8 hours ago - Artificial Intelligence: Read latest updates on AI like Google AI, ChatGPT, Google Lamda, Bard chatbot and more along with latest news as AI technology advances and makes new progress. All get detailed articles on AI related queries like what is AI, types of artificial intelligence, its applications and future. GITEX AI ASIA, the Tech, Startup & Digital Investments Event, returns to Marina Bay Sands, Singapore on 9–10 April 2026.… ... Tim Cook is stepping down as CEO, after serving Apple ...
