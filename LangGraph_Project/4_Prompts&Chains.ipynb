# %% [markdown]
# # **Prompts in langgraph**
#
# In this tutorial, we will learn how to use prompts in langgraph. We will create a simple graph that takes a topic as input and generates a post and a curated post as output. We will use the ChatOpenAI model to generate the post and the curated post.

# %%
from langchain_openai import ChatOpenAI

from dotenv import load_dotenv
import os
load_dotenv()

if os.environ['OPENAI_API_KEY']:
    print("OpenAI API Key is set.")
else:
    raise ValueError("OpenAI API Key is not set.")
# Out:
# OpenAI API Key is set.

# %%
from langchain_core.messages import HumanMessage

llm = ChatOpenAI(model="gpt-5-mini")

# %%
from langchain_core.prompts import ChatPromptTemplate


my_prompt = ChatPromptTemplate.from_messages(
    [
        ("system","You are a helpful assistant that helps to create and curate posts for a social media platform."),
        ("human","I want to create a post about {topic}")
    ]
)

# %% [markdown]
# # **Chain With Prompts**

# %%
chain = my_prompt | llm

# %%
chain.invoke({"topic": "The importance of data privacy in the digital age"})
# Out:
# AIMessage(content='Nice topic — here are ready-to-post options and supporting assets you can use across platforms.\n\nCore message (one-line):\n- Data privacy isn’t just a tech issue — it’s a personal safety and trust issue. Protect your digital life like you protect your home.\n\nShort (X / Twitter)\n- In the digital age your data is currency. Protect it: use strong passwords, enable 2FA, limit app permissions, and think twice before sharing. Privacy = safety. #DataPrivacy #CyberSafety\n\nMedium (Instagram / Facebook)\n- We share more of ourselves online than ever — and that makes data privacy one of the most important issues of our time. From identity theft and financial loss to surveillance and manipulation, unprotected data carries real-world harms. Take small steps today: use unique passwords + a password manager, enable 2FA, review app permissions, update devices, and be cautious on public Wi‑Fi. Your privacy is worth a few minutes of setup. Share this to remind someone to check their settings. #DataPrivacy #PrivacyMatters #CyberSecurity\n\nLong (LinkedIn / professional post)\n- Why data privacy should matter to every professional and organization:\n  - Personal safety: Breaches expose identity, location, and sensitive personal details.\n  - Business risk: Leaks damage trust, brand reputation, and can lead to fines and legal exposure.\n  - Autonomy & democracy: Uncontrolled data collection enables manipulation, profiling, and surveillance.\n  - Economic impact: Data-driven targeting and discriminatory practices can harm customers and employees.\n  Practical steps for individuals & teams:\n  - Require strong, unique passwords and a password manager.\n  - Enforce multi-factor authentication (MFA) across accounts.\n  - Regularly audit app permissions and data-sharing settings.\n  - Keep software and devices patched; use encrypted communications where possible.\n  - Adopt privacy-by-design practices and minimize data collection at the organizational level.\n  Small investments in privacy pay off in trust, resilience, and compliance. Start with an internal privacy check this week — it’s worth the time.\n\nQuick practical tips (for any platform)\n- Use a password manager and unique passwords.\n- Turn on 2FA/MFA everywhere possible.\n- Limit app permissions (location, microphone, contacts).\n- Update OS and apps regularly.\n- Avoid untrusted public Wi‑Fi or use a VPN.\n- Use encrypted messaging for sensitive conversations.\n- Back up important data and secure backups with encryption/passwords.\n- Be skeptical of links and unsolicited requests (phishing).\n\nHashtags and CTA\n- Hashtags: #DataPrivacy #PrivacyMatters #CyberSecurity #DigitalSafety #InfoSec\n- CTA examples: “Check one privacy setting today and tell us which one you changed.” / “Share this post to remind someone to enable 2FA.”\n\nImage suggestions\n- Visuals: lock over a network map, person holding a phone with a shield icon, illustrated “privacy checklist.”\n- Alt text example: “Illustration of a smartphone with a shield icon representing personal data protection.”\n\nIf you want, I can:\n- Tailor a version for a specific platform and character limit.\n- Create a carousel script for Instagram explaining each tip in a slide.\n- Draft a short privacy checklist you can attach as an image or downloadable PDF.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 994, 'prompt_tokens': 44, 'total_tokens': 1038, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DZaza7aKUDXW6nR0Yal0XMbKXFwdg', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019dd3de-327f-7e01-9a72-773e81f2e8f0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata= ...
